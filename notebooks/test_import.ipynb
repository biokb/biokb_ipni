# %%
from ipni.db.manager import DbManager

dm = DbManager()
dm.import_data()
# Out:
# INFO:ipni.db.manager:Database recreated.
# INFO:ipni.db.manager:Start import into ipni_reference
# INFO:ipni.db.manager:Start import into ipni_name
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 from ipni.db.manager import DbManager
#       4 dm = DbManager()
# ----> 5 dm.import_data()
#
# File ~/workspace/uni_bonn/biodb/25/projects_by_christian/ipni/src/ipni/db/manager.py:84, in DbManager.import_data(self)
#      82 for tsv_file, model in file_table_map.items():
#      83     logger.info(f"Start import into {model.__tablename__}")
# ---> 84     self.import_model_data(tsv_file, model)
#      86 if self.path_data_folder == DEFAULT_PATH_UNZIPPED_DATA_FOLDER:
#      87     shutil.rmtree(DEFAULT_PATH_UNZIPPED_DATA_FOLDER)
#
# ...
