# %%
from sqlalchemy import create_engine
from biokb_ipni.db.manager import DbManager

engine = create_engine(
    "mysql+pymysql://ipni_user:ipni_passwd@localhost:3307/ipni?charset=utf8mb4"
)
dm = DbManager(engine)
dm.import_data()
