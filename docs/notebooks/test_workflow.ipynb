# %%
from biokb_ipni.db.manager import DbManager

from biokb_ipni.rdf.turtle import TurtleCreator
from biokb_ipni.rdf.neo4j_importer import Neo4jImporter
import os

# %%
# to make sure no environment variable is set
os.environ.pop("CONNECTION_STR", None)
os.environ.pop("NEO4J_USER", None)
os.environ.pop("NEO4J_PASSWORD", None)
os.environ.pop("NEO4J_URI", None)
pass

# %% [markdown]
# # Workflow without podman-compose
#
# Default settings import the data into `~/.biokb/biokb.db`

# %%
DbManager().import_data(keep_files=True)
TurtleCreator().create_ttls()
# Out:
# INFO:biokb_ipni.db.manager:Database recreated.
# INFO:biokb_ipni.db.manager:Start import into ipni_reference
# INFO:biokb_ipni.db.manager:Start import into ipni_name
# INFO:biokb_ipni.db.manager:Start import into ipni_taxon
# INFO:biokb_ipni.db.manager:Start import into ipni_type_material
# INFO:biokb_ipni.db.manager:Start import into ipni_name_relation
# INFO:biokb_ipni.db.manager:Data imported: {'ipni_reference': 463559, 'ipni_name': 1784252, 'ipni_taxon': 1784252, 'ipni_type_material': 281711, 'ipni_name_relation': 397601}
# {'ipni_reference': 463559,
#  'ipni_name': 1784252,
#  'ipni_taxon': 1784252,
#  'ipni_type_material': 281711,
#  'ipni_name_relation': 397601}

# %% [markdown]
# Before starting the import into neo4j start a test container with:
# ```bash
# podman run --replace --rm --name biokb-neo4j-test -p7474:7474 -p7687:7687 -e NEO4J_AUTH=neo4j/neo4j_password neo4j:latest
# ```

# %%
Neo4jImporter().import_ttls()

# %% [markdown]
# Open Neo4j [browser](http://localhost:7474), login with neo4j/neo4j_password
