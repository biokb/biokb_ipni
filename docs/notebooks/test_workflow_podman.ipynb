# %%
from biokb_ipni.db.manager import DbManager

from biokb_ipni.rdf.turtle import TurtleCreator
from biokb_ipni.rdf.neo4j_importer import Neo4jImporter
from sqlalchemy import create_engine
import os

# %%
# to make sure no environment variable is set
os.environ.pop("CONNECTION_STR", None)
os.environ.pop("NEO4J_USER", None)
os.environ.pop("NEO4J_PASSWORD", None)
os.environ.pop("NEO4J_URI", None)
pass

# %% [markdown]
# # Workflow with podman-compose

# %% [markdown]
# In production you should copy `.env_template` to `.env` and change passwords! For testing we are using `.env_template`.
#
# ```bash
# podman-compose -f docker-compose.db_neo.yml --env-file .env_template up -d
# ```
#
# **Tip:** Before running the following command, please close all other applications that might use significant system resources, as running containers can be resource-intensive.

# %%
engine = create_engine("mysql+pymysql://biokb_user:biokb_password@localhost:3306/biokb")

# %%
DbManager(engine).import_data(keep_files=True)
TurtleCreator(engine).create_ttls()

# %% [markdown]
# Open Neo4j [browser](http://localhost:7474), login with neo4j/neo4j_password

# %%
Neo4jImporter().import_ttls()
# Out:
# INFO:biokb_ipni.rdf.neo4j_importer:Start importing all turtle file in Neo4J.
# INFO:biokb_ipni.rdf.neo4j_importer:Delete an existing graph in Neo4J with node label DbIpni.
# Uniqueness constraint on :Resource(uri) found.
#
#
# The store is now: Open
# Processing ipni_name.ttl: 100%|██████████| 4/4 [08:13<00:00, 123.30s/it]
# The store is now: Closed
# IMPORTED 9952910 TRIPLES
# True
